# %%
# 데이터 변환
import os, json, shutil
from collections import defaultdict

def coco_to_yolo(
    coco_root="../datasets/coco",          # 원본 COCO 스타일 폴더
    out_root="../datasets/coco_yolo"       # YOLO 변환 결과 폴더
):
    # 원본 경로 가정:
    # coco_root/
    #   train/  val/
    #   annotations/train_annotations.json, val_annotations.json

    os.makedirs(out_root, exist_ok=True)
    for split in ["train", "val"]:
        os.makedirs(os.path.join(out_root, "images", split), exist_ok=True)
        os.makedirs(os.path.join(out_root, "labels", split), exist_ok=True)

        ann_path = os.path.join(coco_root, "annotations", f"{split}_annotations.json")
        with open(ann_path, "r", encoding="utf-8") as f:
            coco = json.load(f)

        # category_id -> 0..K-1 contiguous
        cats = sorted(coco["categories"], key=lambda x: x["id"])
        cat_id_to_cls = {c["id"]: i for i, c in enumerate(cats)}
        cls_to_name = {i: c["name"] for i, c in enumerate(cats)}

        # image_id -> (w,h,filename)
        images = {img["id"]: img for img in coco["images"]}

        # image_id -> list of ann
        img_to_anns = defaultdict(list)
        for ann in coco["annotations"]:
            # crowd 등 원치 않으면 필터 가능
            if ann.get("iscrowd", 0) == 1:
                continue
            img_to_anns[ann["image_id"]].append(ann)

        # 이미지 복사 + 라벨 txt 생성
        for img_id, img in images.items():
            w, h = img["width"], img["height"]
            file_name = img["file_name"]
            src_img = os.path.join(coco_root, split, file_name)
            dst_img = os.path.join(out_root, "images", split, file_name)

            # 이미지 복사
            os.makedirs(os.path.dirname(dst_img), exist_ok=True)
            shutil.copy2(src_img, dst_img)

            # 라벨 파일(txt)
            label_path = os.path.join(out_root, "labels", split, os.path.splitext(file_name)[0] + ".txt")

            lines = []
            for ann in img_to_anns.get(img_id, []):
                x, y, bw, bh = ann["bbox"]  # COCO: x,y,w,h (pixel)
                if bw <= 0 or bh <= 0:
                    continue

                cls = cat_id_to_cls[ann["category_id"]]

                # YOLO: x_center,y_center,w,h (normalized)
                x_c = (x + bw / 2) / w
                y_c = (y + bh / 2) / h
                bw_n = bw / w
                bh_n = bh / h

                # 범위 클램프(안전)
                x_c = min(max(x_c, 0.0), 1.0)
                y_c = min(max(y_c, 0.0), 1.0)
                bw_n = min(max(bw_n, 0.0), 1.0)
                bh_n = min(max(bh_n, 0.0), 1.0)

                lines.append(f"{cls} {x_c:.6f} {y_c:.6f} {bw_n:.6f} {bh_n:.6f}")

            with open(label_path, "w", encoding="utf-8") as f:
                f.write("\n".join(lines))

        # dataset.yaml (한 번만 만들면 되지만 split마다 동일하게 생성해도 무방)
        yaml_path = os.path.join(out_root, "dataset.yaml")
        if not os.path.exists(yaml_path):
            names_lines = "\n".join([f"  {i}: {cls_to_name[i]}" for i in sorted(cls_to_name)])
            yaml = f"""path: {out_root}
train: images/train
val: images/val

names:
{names_lines}
"""
            with open(yaml_path, "w", encoding="utf-8") as f:
                f.write(yaml)

    print("✅ COCO -> YOLO 변환 완료")
    print(f"  - dataset.yaml: {os.path.join(out_root, 'dataset.yaml')}")

coco_to_yolo()
# Out:
# ✅ COCO -> YOLO 변환 완료
#   - dataset.yaml: ../datasets/coco_yolo\dataset.yaml

# %%
import os
from ultralytics import YOLO

# ---------------------------
# 설정
# ---------------------------
DATA_YAML = "../datasets/coco_yolo/dataset.yaml"
MODEL_PT  = "yolov8n.pt"   # 시작 가중치(빠름). 성능 더 원하면 yolov8s.pt / yolov8m.pt
EPOCHS    = 120

PASS_AP50 = 0.75
STOP_AP50 = 0.80

pass_saved = False

# 학습 결과 폴더(자동 생성)
PROJECT = "runs_det"
NAME    = "exp_ap50_target"

# ---------------------------
# 콜백: epoch마다 AP50만 출력 + 조건 저장/중지
# ---------------------------
def on_fit_epoch_end(trainer):
    """
    trainer.metrics: epoch 종료 시 검증 지표가 들어옵니다.
    버전에 따라 키 이름이 조금 다를 수 있어, 안전하게 여러 후보를 확인합니다.
    목표: AP@0.50(=mAP50)만 가져오기
    """
    global pass_saved

    m = trainer.metrics  # dict-like

    # 여러 버전 대비: 후보 키들
    cand_keys = [
        "metrics/mAP50(B)", "metrics/mAP50", "mAP50(B)", "mAP50",
        "metrics/precision(B)",  # fallback용(의미 다름) - 가능하면 쓰지 않음
    ]

    ap50 = None
    for k in cand_keys:
        if k in m:
            ap50 = float(m[k])
            break

    # 그래도 못 찾으면: metrics dict 전체에서 mAP50 포함 키 탐색
    if ap50 is None:
        for k, v in m.items():
            if "mAP50" in str(k):
                ap50 = float(v)
                break

    if ap50 is None:
        # AP50를 못 읽었으면 조용히 넘어감(버전/환경 차이)
        return

    epoch = trainer.epoch + 1
    print(f"epoch={epoch:03d}  AP50={ap50:.4f}")

    # 0.75 통과 저장 (멈추지 않음)
    if (ap50 >= PASS_AP50) and (not pass_saved):
        # best.pt를 pass 파일로 복사 저장
        best_pt = os.path.join(trainer.save_dir, "weights", "best.pt")
        if os.path.exists(best_pt):
            dst = os.path.join(trainer.save_dir, "weights", "pass_ap50_0.75.pt")
            import shutil
            shutil.copy2(best_pt, dst)
        pass_saved = True

    # 0.80 도달 시 저장 + 즉시 종료
    if ap50 >= STOP_AP50:
        best_pt = os.path.join(trainer.save_dir, "weights", "best.pt")
        if os.path.exists(best_pt):
            dst = os.path.join(trainer.save_dir, "weights", "pass_ap50_0.80.pt")
            import shutil
            shutil.copy2(best_pt, dst)

        print("🎯 STOP(AP50>=0.80) reached -> saved & stop")
        trainer.stop = True   # ✅ 즉시 종료


# ---------------------------
# 학습 실행
# ---------------------------
model = YOLO(MODEL_PT)

model.add_callback("on_fit_epoch_end", on_fit_epoch_end)

model.train(
    data=DATA_YAML,
    epochs=EPOCHS,
    imgsz=640,
    batch=16,          # GPU 메모리 부족하면 8로
    device=0,          # GPU
    workers=0,         # 요청하신 조건
    project=PROJECT,
    name=NAME,
    verbose=False      # 기본 로그 줄이기 (AP50만 찍고 싶으니까)
)
# Out:
# Ultralytics 8.4.12  Python-3.9.21 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3090, 24576MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=../datasets/coco_yolo/dataset.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=120, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=exp_ap50_target2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_det, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\PyProject\AIFFEL_AI\pytorchtrf-main\pytorchtrf-main\09  \runs\detect\runs_det\exp_ap50_target2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=False, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 573.3270.5 MB/s, size: 123.8 KB)
# train: Scanning D:\PyProject\AIFFEL_AI\pytorchtrf-main\pytorchtrf-main\datasets\coco_yolo\labels\train.cache... 2431 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2431/2431  0.0s
# val: Fast image access  (ping: 0.10.0 ms, read: 608.0128.6 MB/s, size: 108.9 KB)
# val: Scanning D:\PyProject\AIFFEL_AI\pytorchtrf-main\pytorchtrf-main\datasets\coco_yolo\labels\val.cache... 181 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 181/181  0.0s
# Plotting labels to D:\PyProject\AIFFEL_AI\pytorchtrf-main\pytorchtrf-main\09  \runs\detect\runs_det\exp_ap50_target2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to D:\PyProject\AIFFEL_AI\pytorchtrf-main\pytorchtrf-main\09  \runs\detect\runs_det\exp_ap50_target2
# Starting training for 120 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/120      1.91G      1.041        2.2       1.35         47        640: 100% ━━━━━━━━━━━━ 152/152 3.3it/s 45.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 2.5it/s 2.4s0.5ss
#                    all        181        200      0.355      0.521      0.389      0.208
# epoch=001  AP50=0.3886
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/120      2.61G      1.276      2.039      1.512         41        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.401      0.335      0.323      0.161
# epoch=002  AP50=0.3234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/120      2.63G       1.37      2.011      1.589         37        640: 100% ━━━━━━━━━━━━ 152/152 3.3it/s 45.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.2it/s 1.4s0.3s
#                    all        181        200      0.335       0.41      0.296      0.154
# epoch=003  AP50=0.2962
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/120      2.65G      1.368      1.943      1.591         41        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200       0.34      0.445      0.336      0.173
# epoch=004  AP50=0.3357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/120      2.65G      1.341      1.839       1.56         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200       0.51      0.429      0.424      0.226
# epoch=005  AP50=0.4241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/120      2.65G      1.308      1.775      1.537         34        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1it/s 1.4s0.3s
#                    all        181        200      0.398      0.513      0.376      0.191
# epoch=006  AP50=0.3762
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/120      2.65G      1.278      1.726       1.52         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200        0.5       0.47      0.412      0.217
# epoch=007  AP50=0.4119
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/120      2.67G      1.258      1.699      1.495         42        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.579      0.489      0.509      0.284
# epoch=008  AP50=0.5095
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/120      2.68G      1.235      1.636      1.487         30        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.477       0.47      0.425      0.208
# epoch=009  AP50=0.4254
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/120       2.7G      1.213      1.607      1.465         41        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.527       0.55      0.543      0.317
# epoch=010  AP50=0.5434
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/120      2.72G      1.211      1.576      1.455         51        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.642       0.46      0.531      0.295
# epoch=011  AP50=0.5312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/120      2.73G      1.182      1.551      1.447         47        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.601       0.55      0.537      0.326
# epoch=012  AP50=0.5369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/120      2.75G      1.136      1.445      1.408         53        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.461       0.48      0.436      0.273
# epoch=013  AP50=0.4362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/120      2.75G      1.161      1.445      1.431         38        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.565       0.64      0.582       0.37
# epoch=014  AP50=0.5822
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/120      2.75G      1.141       1.48      1.412         45        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 45.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.457      0.633      0.538      0.337
# epoch=015  AP50=0.5379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/120      2.75G      1.115      1.422      1.392         35        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 44.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.559      0.685      0.621      0.419
# epoch=016  AP50=0.6208
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/120      2.75G      1.106      1.379      1.385         34        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.609      0.579       0.57      0.351
# epoch=017  AP50=0.5698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/120      2.75G       1.08      1.375      1.377         37        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.549       0.64      0.601      0.361
# epoch=018  AP50=0.6011
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/120      2.75G      1.103      1.347      1.389         39        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.585      0.575       0.57      0.364
# epoch=019  AP50=0.5700
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/120      2.75G      1.069      1.317       1.37         38        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.673      0.647      0.657      0.441
# epoch=020  AP50=0.6574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/120      2.75G       1.07       1.32      1.362         48        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.2it/s 1.4s0.3s
#                    all        181        200      0.719       0.61      0.636      0.438
# epoch=021  AP50=0.6363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/120      2.75G       1.06      1.277      1.358         40        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.0it/s 1.5s0.3s
#                    all        181        200      0.621       0.72      0.699      0.478
# epoch=022  AP50=0.6990
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/120      2.77G      1.046      1.278      1.349         45        640: 100% ━━━━━━━━━━━━ 152/152 3.3it/s 45.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200       0.65      0.624      0.652      0.436
# epoch=023  AP50=0.6519
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/120      2.77G      1.041      1.245      1.348         28        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200       0.65      0.585      0.627      0.392
# epoch=024  AP50=0.6270
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/120      2.77G      1.046      1.242      1.348         45        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.656      0.665      0.662      0.437
# epoch=025  AP50=0.6621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/120      2.77G       1.04      1.244      1.344         46        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 44.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.2it/s 1.4s0.3s
#                    all        181        200      0.662      0.645      0.676      0.465
# epoch=026  AP50=0.6761
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/120      2.77G      1.028      1.238      1.339         53        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 44.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.744      0.634      0.705      0.479
# epoch=027  AP50=0.7047
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/120      2.77G     0.9954      1.187      1.309         44        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.693       0.58      0.639      0.433
# epoch=028  AP50=0.6391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/120      2.77G      1.019      1.214      1.324         39        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.598      0.645      0.629      0.428
# epoch=029  AP50=0.6288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/120      2.77G      1.022       1.19      1.333         43        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.693       0.61      0.692      0.464
# epoch=030  AP50=0.6919
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/120      2.77G     0.9889      1.143      1.305         37        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.0it/s 1.5s0.3s
#                    all        181        200      0.719      0.689      0.739      0.513
# epoch=031  AP50=0.7390
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/120      2.77G     0.9992      1.149      1.302         45        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.699      0.643        0.7      0.473
# epoch=032  AP50=0.6998
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/120      2.77G     0.9768      1.137      1.295         44        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.2it/s 1.4s0.3s
#                    all        181        200      0.657       0.65       0.66      0.432
# epoch=033  AP50=0.6597
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/120      2.77G     0.9759       1.12      1.295         38        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1it/s 1.4s0.3s
#                    all        181        200      0.711      0.677      0.704      0.488
# epoch=034  AP50=0.7036
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/120      2.77G     0.9795      1.103      1.305         43        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.663      0.702      0.707      0.483
# epoch=035  AP50=0.7068
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/120      2.77G     0.9545      1.095      1.284         45        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 44.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.647      0.755      0.703      0.496
# epoch=036  AP50=0.7034
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/120      2.77G     0.9524      1.093      1.277         52        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.675      0.734      0.741      0.518
# epoch=037  AP50=0.7413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/120      2.77G     0.9336      1.052       1.26         52        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.664      0.776       0.73      0.509
# epoch=038  AP50=0.7303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/120      2.77G     0.9528       1.07      1.285         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 44.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.692      0.718      0.739      0.514
# epoch=039  AP50=0.7389
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/120      2.77G     0.9326      1.035      1.272         53        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.3s0.3s
#                    all        181        200      0.632       0.68      0.705      0.495
# epoch=040  AP50=0.7049
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/120      2.77G     0.9466      1.054      1.279         43        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.732      0.679      0.723      0.507
# epoch=041  AP50=0.7228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/120      2.77G     0.9322      1.032      1.264         47        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.747      0.678      0.736      0.522
# epoch=042  AP50=0.7363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/120      2.77G     0.9246      1.031      1.259         38        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.8it/s 1.6s0.4s
#                    all        181        200      0.706      0.734      0.745      0.529
# epoch=043  AP50=0.7454
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/120      2.77G     0.9216      1.028      1.262         35        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 45.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.717      0.724      0.719       0.51
# epoch=044  AP50=0.7195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/120      2.77G     0.9098      1.019      1.248         34        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.695        0.7      0.711      0.511
# epoch=045  AP50=0.7111
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/120      2.77G     0.9031     0.9987      1.237         36        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.745      0.725      0.744       0.54
# epoch=046  AP50=0.7439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/120      2.77G     0.8877     0.9619      1.239         45        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200       0.74       0.73      0.751      0.538
# epoch=047  AP50=0.7513
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/120      2.77G     0.8897     0.9816      1.238         46        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.715      0.705      0.722      0.503
# epoch=048  AP50=0.7219
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/120      2.77G     0.8915     0.9638      1.239         36        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.1it/s 1.5s0.3s
#                    all        181        200      0.732      0.745      0.765      0.553
# epoch=049  AP50=0.7651
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/120      2.77G     0.8832     0.9353      1.226         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 44.0s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200       0.67      0.737      0.701      0.483
# epoch=050  AP50=0.7014
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/120      2.77G     0.8962     0.9684      1.241         43        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.3s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200       0.71       0.77      0.739       0.51
# epoch=051  AP50=0.7395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/120      2.77G     0.8635     0.9342       1.23         43        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.732      0.745      0.749      0.532
# epoch=052  AP50=0.7493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/120      2.77G     0.8806     0.9375      1.232         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.725      0.735      0.716      0.497
# epoch=053  AP50=0.7163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/120      2.77G     0.8723     0.9237      1.226         29        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.772      0.703      0.713      0.516
# epoch=054  AP50=0.7133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/120      2.77G     0.8609     0.9184      1.214         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.789      0.694      0.766      0.536
# epoch=055  AP50=0.7659
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/120      2.77G     0.8683     0.9177      1.224         48        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.4s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.772      0.667      0.725      0.539
# epoch=056  AP50=0.7252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/120      2.77G     0.8607     0.9093      1.218         34        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.725       0.73      0.718      0.513
# epoch=057  AP50=0.7180
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/120      2.77G     0.8524     0.8946      1.204         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.678        0.7      0.713      0.514
# epoch=058  AP50=0.7130
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/120      2.77G     0.8584     0.9011      1.211         35        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.708       0.77      0.732      0.518
# epoch=059  AP50=0.7317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/120      2.77G     0.8415      0.865      1.197         31        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.758      0.705      0.751      0.543
# epoch=060  AP50=0.7514
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/120      2.77G     0.8375     0.8719      1.192         48        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.771       0.72      0.764      0.551
# epoch=061  AP50=0.7643
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/120      2.77G     0.8262     0.8469      1.191         37        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.785       0.73      0.769      0.553
# epoch=062  AP50=0.7695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/120      2.77G     0.8305     0.8489      1.194         48        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.739      0.745      0.743      0.542
# epoch=063  AP50=0.7426
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/120      2.77G     0.8211     0.8304      1.185         41        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200       0.71      0.746      0.769      0.555
# epoch=064  AP50=0.7693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/120      2.77G     0.8235     0.8265      1.185         32        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.687      0.762      0.725      0.523
# epoch=065  AP50=0.7253
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/120      2.77G     0.8169     0.8327      1.184         37        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.793      0.733      0.753      0.539
# epoch=066  AP50=0.7531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/120      2.77G     0.8244     0.8311      1.184         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.792      0.743      0.761      0.553
# epoch=067  AP50=0.7613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/120      2.77G      0.822     0.8157      1.188         41        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.718      0.758      0.731      0.527
# epoch=068  AP50=0.7307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/120      2.77G     0.8162     0.8185      1.176         38        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200       0.77      0.677      0.735      0.531
# epoch=069  AP50=0.7351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/120      2.77G     0.8098     0.8058      1.176         37        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.735      0.782      0.762      0.558
# epoch=070  AP50=0.7624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/120      2.77G     0.7875     0.7982      1.162         46        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.732      0.758      0.744      0.527
# epoch=071  AP50=0.7441
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/120      2.77G     0.8016     0.7852      1.173         35        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.715        0.8      0.755       0.56
# epoch=072  AP50=0.7551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/120      2.77G     0.7894      0.789      1.162         43        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.5s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.819      0.725      0.789      0.566
# epoch=073  AP50=0.7895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/120      2.77G     0.7869     0.7829      1.163         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.765      0.753      0.764      0.545
# epoch=074  AP50=0.7641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/120      2.77G     0.8003     0.7933       1.17         42        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.817      0.685      0.765      0.566
# epoch=075  AP50=0.7652
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/120      2.77G     0.7663     0.7613      1.146         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.731      0.765      0.751      0.554
# epoch=076  AP50=0.7510
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/120      2.77G     0.7778     0.7563      1.156         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.775       0.77       0.76      0.568
# epoch=077  AP50=0.7602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/120      2.77G     0.7737      0.746       1.15         38        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.783       0.71      0.751      0.545
# epoch=078  AP50=0.7510
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/120      2.77G     0.7736     0.7438      1.148         44        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.788      0.774      0.783      0.576
# epoch=079  AP50=0.7826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/120      2.77G     0.7676     0.7508      1.143         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.772      0.768      0.771      0.555
# epoch=080  AP50=0.7712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/120      2.77G     0.7578     0.7327      1.136         40        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.821      0.755      0.772      0.563
# epoch=081  AP50=0.7718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/120      2.77G     0.7649     0.7248       1.14         51        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.6s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.3it/s 1.4s0.3s
#                    all        181        200      0.761      0.764      0.747      0.552
# epoch=082  AP50=0.7470
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/120      2.77G     0.7467     0.7124       1.13         29        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.3s0.3s
#                    all        181        200      0.778      0.755      0.762      0.574
# epoch=083  AP50=0.7624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/120      2.77G       0.76     0.7143      1.141         47        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.743       0.76      0.733      0.536
# epoch=084  AP50=0.7332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/120      2.77G     0.7411     0.6942      1.128         35        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.787        0.8      0.785      0.582
# epoch=085  AP50=0.7849
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/120      2.77G     0.7456     0.6956      1.127         37        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.8s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.766      0.777      0.754      0.545
# epoch=086  AP50=0.7539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/120      2.77G     0.7396     0.7013      1.131         48        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.754      0.784      0.769       0.57
# epoch=087  AP50=0.7689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/120      2.77G     0.7366     0.6781      1.118         39        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.813      0.726      0.753      0.556
# epoch=088  AP50=0.7534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/120      2.77G     0.7265     0.6747      1.115         38        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.9s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.4it/s 1.4s0.3s
#                    all        181        200      0.738       0.75      0.753      0.557
# epoch=089  AP50=0.7526
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/120      2.77G     0.7264     0.6735      1.113         48        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.769      0.705      0.736      0.545
# epoch=090  AP50=0.7355
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/120      2.77G     0.7251      0.665      1.117         41        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.2s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.805      0.716      0.755      0.557
# epoch=091  AP50=0.7548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/120      2.77G     0.7344     0.6724      1.122         53        640: 100% ━━━━━━━━━━━━ 152/152 3.4it/s 44.1s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 3.9it/s 1.6s0.4s
#                    all        181        200      0.763       0.75      0.752      0.559
# epoch=092  AP50=0.7521
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/120      2.79G     0.7158      0.661      1.104         36        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.776      0.763      0.766      0.555
# epoch=093  AP50=0.7660
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/120      2.79G      0.713     0.6748       1.11         33        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 6/6 4.5it/s 1.3s0.3s
#                    all        181        200      0.726      0.765      0.763      0.575
# epoch=094  AP50=0.7628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/120      2.79G     0.7027     0.6479      1.103         41        640: 100% ━━━━━━━━━━━━ 152/152 3.5it/s 43.7s0.3ss
# ...
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[     0.1587,      0.1587,       0.218, ...,           1,           1,           1],
#        [    0.11669,     0.11669,     0.16055, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[       0.93,        0.93,        0.92, ...,           0,           0,           0],
#        [       0.93,        0.93,        0.92, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: np.float64(0.6070996053710883)
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.64081,     0.57339])
# names: {0: 'cat', 1: 'dog'}
# nt_per_class: array([100, 100])
# nt_per_image: array([96, 90])
# results_dict: {'metrics/precision(B)': 0.7868395238926036, 'metrics/recall(B)': 0.7797073811779694, 'metrics/mAP50(B)': 0.7868582950295222, 'metrics/mAP50-95(B)': 0.6070996053710883, 'fitness': 0.6070996053710883}
# save_dir: WindowsPath('D:/PyProject/AIFFEL_AI/pytorchtrf-main/pytorchtrf-main/09장 객체 탐지/runs/detect/runs_det/exp_ap50_target2')
# speed: {'preprocess': 0.28482762430417474, 'inference': 2.4699331491756915, 'loss': 0.0003276243117684241, 'postprocess': 1.2169861878526176}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'

# %%
import numpy as np

def _to_scalar(x):
    """Ultralytics metric이 scalar/np.array/list 어떤 형태든 안전하게 float로 변환"""
    if x is None:
        return None
    # torch tensor
    if hasattr(x, "detach"):
        x = x.detach().cpu().numpy()
    # numpy / list
    x = np.asarray(x)
    # scalar면 그대로, 배열이면 평균
    return float(x.mean()) if x.size > 1 else float(x.item())

def pretty_print_yolo_val(metrics, target_map50=0.75):
    p       = _to_scalar(getattr(metrics.box, "p", None))
    r       = _to_scalar(getattr(metrics.box, "r", None))
    map50   = _to_scalar(getattr(metrics.box, "map50", None))
#    map5095 = _to_scalar(getattr(metrics.box, "map", None))

    status = "✅ PASS" if (map50 is not None and map50 >= target_map50) else "❌ FAIL"

    print("\n" + "="*52)
    print(f"{status}  (Target: mAP50 ≥ {target_map50:.2f})")
    print("-"*52)
    if p is not None:       print(f"Precision (P) : {p:.3f}")
    if r is not None:       print(f"Recall (R)    : {r:.3f}")
    if map50 is not None:   print(f"mAP50         : {map50:.3f} ({map50*100:.1f}%)")
#    if map5095 is not None: print(f"mAP50-95      : {map5095:.3f} ({map5095*100:.1f}%)")
    print("="*52 + "\n")

pretty_print_yolo_val(metrics, target_map50=0.75)
# Out:
# ====================================================
# ✅ PASS  (Target: mAP50 ≥ 0.75)
# ----------------------------------------------------
# Precision (P) : 0.762
# Recall (R)    : 0.798
# mAP50         : 0.792 (79.2%)
# ====================================================
